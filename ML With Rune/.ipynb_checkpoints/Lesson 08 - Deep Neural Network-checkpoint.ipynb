# %% [markdown]
# # Deep Neural Network (DNN)
# <hr>
#
# - The adjective "deep" in deep learning refers to the use of multiple layers in the network
# - Usually having two or more hidden layers count as deep.
#
# ![dnn](./images/dnn.PNG)

# %% [markdown]
# ## Backpropagation
# - Algorithm for training neural networks with hidden layers
# - Algorithm
#     - Start with a random choice of weights
#     - Repeat
#          - Calculate error for output layer
#          - For each layer - starting with output layer
#              - Propagate error back one layer
#              - Update weights
#
# ### Overfitting
# - Fit too close to training data and not generalize well
#
# ### Dropout
# - Temporarily remove units - selectat random - from a neural network to prevent over reliance on certain units
# - Dropout value of 20%-50%
# - Better performance when dropout is used on a larger network
# - Dropout at each layer of the network has shown good results.
#
# ![dnn](./images/dnn2.PNG)

# %% [markdown]
# ### Tensorflow
# - Ideas: No hidden layer -> only straight line. Hidden layer -> XOR function and more
# - https://playground.tensorflow.org/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('./data/xor.csv')
data.head()
# Out:
#           x         y  class id
# 0  0.743986 -1.413632         1
# 1 -3.915247  1.634048         1
# 2  0.470328  4.048055         0
# 3 -1.197252  3.975475         1
# 4 -3.910402 -4.284134         0

# %%
fig, ax = plt.subplots()

ax.scatter(x=data['x'],y=data['y'], c=data['class id'])

# %%
X_train, X_test, y_train, y_test = train_test_split(data[['x','y']], data['class id'], random_state=42)

# %%
accuracies = []

for i in range(5):
    model = Sequential()
    model.add(Dense(1, input_dim=2, activation='relu'))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train,y_train, epochs=100, batch_size=32, verbose=0)
    _, accuracy = model.evaluate(X_test,y_test)
    accuracies.append(accuracy*100)
    
sum(accuracies)/len(accuracies)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 6.6595 - accuracy: 0.5320
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9499 - accuracy: 0.6600
# 8/8 [==============================] - 0s 2ms/step - loss: 4.7207 - accuracy: 0.6560
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7406 - accuracy: 0.6560
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0817 - accuracy: 0.6120
# 62.32000112533569

# %%
 accuracies = []

for i in range(5):
    model = Sequential()
    model.add(Dense(6, input_dim=2, activation='relu'))
    model.add(Dense(4, input_dim=2, activation='relu'))
    model.add(Dense(1, input_dim=2, activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train,y_train, epochs=100, batch_size=32, verbose=0)
    _, accuracy = model.evaluate(X_test,y_test)
    accuracies.append(accuracy*100)
    
sum(accuracies)/len(accuracies)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9920
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9960
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 0.9960
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 0.9880
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9920
# 99.2799985408783
