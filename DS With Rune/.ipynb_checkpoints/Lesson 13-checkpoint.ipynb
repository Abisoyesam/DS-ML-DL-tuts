# %% [markdown]
# # Feature Scaling
#
# <hr>
#
# - **Feature Scaling:** transforms values in the similiar range for machine learnig algorithm to behave optimal.
#
# ## Feature Scaling Techniques
# - **Normalization:** is a special case of **MinMaxScaler**
#     - Normalization converts values between `0 - 1`.
#
#     $$\dfrac{values - values.min()}{values.max()} - values.min()$$
#     - **MinMaxScaler:** Between any values.
#
#
# - **Stardardization (StandarddScalar** from sklearn)
#     - Mean: 0; StdDev: 1
#
#     $$\dfrac{values - values.mean()}{values.std()}$$
#     - Less sensitive to outliers

# %% [markdown]
# <hr>
#
# ## Machine Learning Algorithm
# - Some algorithms are more sensitive than others
# - **Distance-based** algorithms are most affected by the range of features.
#     * Examples include: `SVM`, `KNN`, `K-means`

# %%
import pandas as pd

# %%
data = pd.read_csv('data/weather.csv',index_col=0,parse_dates=True)
data.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2008-02-01     19.5     22.4      15.6          6.2       0.0         NaN
# 2008-02-02     19.5     25.6       6.0          3.4       2.7         NaN
# 2008-02-03     21.6     24.5       6.6          2.4       0.1         NaN
# 2008-02-04     20.2     22.8      18.8          2.2       0.0         NaN
# 2008-02-05     19.7     25.7      77.4          NaN       0.0         NaN
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# Date                                                           ...
# 2008-02-01            NaN          S        SSW          17.0  ...
# 2008-02-02            NaN          W          E           9.0  ...
# 2008-02-03            NaN        ESE        ESE          17.0  ...
# 2008-02-04            NaN        NNE          E          22.0  ...
# 2008-02-05            NaN        NNE          W          11.0  ...
#
#             Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# Date
# 2008-02-01         84.0       1017.6       1017.4       8.0       8.0
# 2008-02-02         73.0       1017.9       1016.4       7.0       7.0
# 2008-02-03         86.0       1016.7       1015.6       7.0       8.0
# 2008-02-04         90.0       1014.2       1011.8       8.0       8.0
# 2008-02-05         74.0       1008.3       1004.8       8.0       8.0
#
#             Temp9am  Temp3pm  RainToday  RISK_MM RainTomorrow
# Date
# 2008-02-01     20.7     20.9        Yes      6.0          Yes
# 2008-02-02     22.4     24.8        Yes      6.6          Yes
# 2008-02-03     23.5     23.0        Yes     18.8          Yes
# 2008-02-04     21.4     20.9        Yes     77.4          Yes
# 2008-02-05     22.5     25.5        Yes      1.6          Yes
#
# [5 rows x 22 columns]

# %%
data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
# only wanna make use of numeric features
dataset = data.select_dtypes(include='number')
dataset.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Date
# 2008-02-01     19.5     22.4      15.6          6.2       0.0            NaN
# 2008-02-02     19.5     25.6       6.0          3.4       2.7            NaN
# 2008-02-03     21.6     24.5       6.6          2.4       0.1            NaN
# 2008-02-04     20.2     22.8      18.8          2.2       0.0            NaN
# 2008-02-05     19.7     25.7      77.4          NaN       0.0            NaN
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# Date
# 2008-02-01          17.0          20.0         92.0         84.0       1017.6
# 2008-02-02           9.0          13.0         83.0         73.0       1017.9
# 2008-02-03          17.0           2.0         88.0         86.0       1016.7
# 2008-02-04          22.0          20.0         83.0         90.0       1014.2
# 2008-02-05          11.0           6.0         88.0         74.0       1008.3
#
#             Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RISK_MM
# Date
# 2008-02-01       1017.4       8.0       8.0     20.7     20.9      6.0
# 2008-02-02       1016.4       7.0       7.0     22.4     24.8      6.6
# 2008-02-03       1015.6       7.0       8.0     23.5     23.0     18.8
# 2008-02-04       1011.8       8.0       8.0     21.4     20.9     77.4
# 2008-02-05       1004.8       8.0       8.0     22.5     25.5      1.6

# %%
data.shape, dataset.shape
# Out:
# ((3337, 22), (3337, 17))

# %%
# drop the missing value
dataset.isna().sum()
# Out:
# MinTemp             3
# MaxTemp             2
# Rainfall            6
# Evaporation        51
# Sunshine           16
# WindGustSpeed    1036
# WindSpeed9am       26
# WindSpeed3pm       25
# Humidity9am        14
# Humidity3pm        13
# Pressure9am        20
# Pressure3pm        19
# Cloud9am          566
# Cloud3pm          561
# Temp9am             4
# Temp3pm             4
# RISK_MM             0
# dtype: int64

# %%
dataset = dataset.dropna(axis=0)

# %%
dataset = dataset.drop(['RISK_MM'],axis=1)

# %%
dataset.shape
# Out:
# (1696, 16)

# %%
dataset.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Date
# 2010-10-20     12.9     20.3       0.2          3.0      10.9           37.0
# 2010-10-21     13.3     21.5       0.0          6.6      11.0           41.0
# 2010-10-22     15.3     23.0       0.0          5.6      11.0           41.0
# 2010-10-26     12.9     26.7       0.2          3.8      12.1           33.0
# 2010-10-27     14.8     23.8       0.0          6.8       9.6           54.0
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# Date
# 2010-10-20          11.0          26.0         70.0         57.0       1028.8
# 2010-10-21          11.0          28.0         75.0         58.0       1025.9
# 2010-10-22           6.0          19.0         70.0         63.0       1021.4
# 2010-10-26          13.0          24.0         73.0         56.0       1018.0
# 2010-10-27          13.0          26.0         76.0         69.0       1016.0
#
#             Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# Date
# 2010-10-20       1025.6       3.0       1.0     16.9     19.8
# 2010-10-21       1022.4       2.0       5.0     17.6     21.3
# 2010-10-22       1017.8       1.0       4.0     19.0     22.2
# 2010-10-26       1015.0       1.0       5.0     17.8     22.5
# 2010-10-27       1014.7       2.0       7.0     20.2     20.6

# %% [markdown]
# ### Explore Normalization and Standardization

# %%
X = dataset
y = data['RainToday'].dropna()

# %%
len(X),len(y)
# Out:
# (1696, 3331)
